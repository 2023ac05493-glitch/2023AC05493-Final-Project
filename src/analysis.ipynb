# %%
import os
NEWS_API_KEY = os.getenv('NEWS_API_KEY','')

# %%
from newsapi import NewsApiClient
newsapi = NewsApiClient(api_key=NEWS_API_KEY)

# %%
from datetime import datetime,timedelta
end_date = datetime.now()
start_date = end_date - timedelta(days=7)
response = newsapi.get_everything(q='Indian stock nifty 50', from_param=start_date.strftime('%Y-%m-%d'), to=end_date.strftime('%Y-%m-%d'), language='en', sort_by='relevancy', page_size=50)

# %%
response
# Out:
# {'status': 'ok',
#  'totalResults': 43,
#  'articles': [{'source': {'id': 'the-times-of-india',
#     'name': 'The Times of India'},
#    'author': 'Anupam Nagar',
#    'title': '2 top stock recommendations from Vinay Rajani',
#    'description': 'Indian stock markets are advancing, approaching record levels. Experts see continued strength in the Nifty, with support at 25,600.  Metals and PSU banks are identified as key performing sectors.  Steel Authority of India and Bank of Maharashtra are highlight…',
#    'url': 'https://economictimes.indiatimes.com/markets/expert-view/2-top-stock-recommendations-from-vinay-rajani/articleshow/128150112.cms',
#    'urlToImage': 'https://img.etimg.com/thumb/msid-128150234,width-1200,height-630,imgsize-20426,overlay-etmarkets/articleshow.jpg',
#    'publishedAt': '2026-02-10T08:47:27Z',
#    'content': 'Indian equity markets continued their positive momentum, with benchmark indices edging closer to record highs, even as resistance emerged near the 26,000 mark. Market participants remained encouraged… [+3070 chars]'},
#   {'source': {'id': 'the-times-of-india', 'name': 'The Times of India'},
#    'author': 'Veer Sharma',
#    'title': 'Market Wrap: Sensex adds 266 pts, Nifty above 25,650; Indian rupee logs best week in over 3 years',
#    'description': 'Indian stock markets, Nifty and Sensex, ended Friday higher. The Reserve Bank of India maintained its policy repo rate at 5.25 percent. Cigarette stocks saw a significant surge following price increases. Global markets retreated, impacted by a Wall Street sel…',
#    'url': 'https://economictimes.indiatimes.com/markets/stocks/news/market-wrap-sensex-adds-266-pts-nifty-above-25650-indian-rupee-logs-best-week-in-over-3-years/articleshow/127983812.cms',
#    'urlToImage': 'https://img.etimg.com/thumb/msid-127984029,width-1200,height-630,imgsize-70696,overlay-etmarkets/articleshow.jpg',
#    'publishedAt': '2026-02-06T10:20:41Z',
#    'content': 'Benchmark indices Nifty and Sensex pared early morning losses to end the day higher on Friday, February 6 as the Indian rupee logged its best week in over 3 years. The Reserve Bank of India left its … [+3956 chars]'},
#   {'source': {'id': None, 'name': 'The Indian Express'},
#    'author': 'Siddharth Upasani',
#    'title': 'Top I-T firms earmark Labour Code costs, less than 3% of payroll',
#    'description': 'The data shows that the 41 Nifty 50 companies that have so far announced their latest financial results provided Rs 13,307 crore in the reporting quarter for the first nine months of 2025-26.',
#    'url': 'https://indianexpress.com/article/business/top-i-t-firms-earmark-labour-code-costs-less-than-3-per-cent-of-payroll-10521478/',
#    'urlToImage': 'https://images.indianexpress.com/2026/02/IT-companies.jpg',
#    'publishedAt': '2026-02-09T00:10:35Z',
#    'content': 'Indias biggest companies set aside more than Rs 13,000 crore in the October-December 2025 quarter to account for the impact of the new Labour Codes, according to data compiled by The Indian Express. … [+4078 chars]'},
#   {'source': {'id': None, 'name': 'The Indian Express'},
#    'author': 'Hitesh Vyas',
#    'title': 'India-US trade deal to accelerate capital formation: SEBI Chairman Tuhin Kanta Pandey',
#    'description': 'FPIs have been offloading domestic equities for the past many months amid concerns over various geopolitical tensions, including the levy of higher reciprocal tariffs by the US on India and other major economies.',
#    'url': 'https://indianexpress.com/article/business/india-us-trade-deal-capital-formation-sebi-chairman-tuhin-kanta-pandey-10513852/',
#    'urlToImage': 'https://images.indianexpress.com/2026/02/SEBI-chairmanTuhin-Kanta-Pandey.jpg',
#    'publishedAt': '2026-02-04T15:20:06Z',
#    'content': 'Securities and Exchange Board of India (SEBI) Chairman Tuhin Kanta Pandey Wednesday expressed confidence that the India-US trade deal will spur investments and accelerate capital formation in the cou… [+2512 chars]'},
#   {'source': {'id': None, 'name': 'BusinessLine'},
#    'author': 'Gurumurthy K',
#    'title': 'Index Outlook: Ready to rise & shine',
#    'description': 'Indian stock indices show potential for growth, supported by recent FPI buying and key resistance levels ahead.',
#    'url': 'https://www.thehindubusinessline.com/portfolio/technical-analysis/index-outlook-ready-to-rise-amp-shine/article70603266.ece',
#    'urlToImage': 'https://bl-i.thgim.com/public/incoming/op9us8/article70604665.ece/alternates/LANDSCAPE_1200/PO08_Sunrise_planet.jpg',
#    'publishedAt': '2026-02-07T15:22:25Z',
#    'content': 'Two major events jolted the Indian stock markets last week. First was the increase in Securities Transaction Tax in Futures and Options announced in the Union Budget. This triggered a strong sell-off… [+5010 chars]'},
#   {'source': {'id': None, 'name': 'BusinessLine'},
#    'author': 'KS Badri Narayanan, Team BL',
#    'title': 'Stock Market Live Updates 5 February 2026: Sensex slips 145 points to 83,671 at open, Nifty down 45 points at 25,730',
#    'description': 'Sensex, Nifty, Stock Price LIVE: Sensex falls 145.71 pts or 0.17 % to 83,671.98 at 9.17 am after opening at 83,757.54, against previous close of 83,817.69. Nifty 50 down by 45.95 pts or 0.18% to 25,730.05',
#    'url': 'https://www.thehindubusinessline.com/markets/stock-market-nifty-sensex-live-updates-5-february-2026/article70592728.ece',
#    'urlToImage': 'https://bl-i.thgim.com/public/incoming/c0k3er/article70592758.ece/alternates/LANDSCAPE_1200/PO20_Stockmarket_eyeglasses.jpg',
#    'publishedAt': '2026-02-05T04:02:18Z',
#    'content': '<li></li>\r\nFebruary 5, 2026 09:37Gold &amp; Silver updates: MCX levies additional margin on gold, silver futures\r\nMulti Commodity Exchange Clearing Corporation, part of the countrys largest commodity… [+70309 chars]'},
#   {'source': {'id': None, 'name': 'BusinessLine'},
#    'author': 'Shakthi H',
#    'title': 'Top Business & Market Headlines Today — BL Morning Report, Feb 09, 2026',
#    'description': 'BL Morning Report February 09, 2026: Get today’s top business news, market headlines about the Stock Market, Sensex & Nifty trends, key market insights, economic highlights, and the latest updates from India and global markets.',
#    'url': 'https://www.thehindubusinessline.com/multimedia/audio/bl-morning-report-january-26-2026/article70606851.ece',
#    'urlToImage': 'https://bl-i.thgim.com/public/incoming/gkgw6w/article70524975.ece/alternates/LANDSCAPE_1200/Shakthi%201.png',
#    'publishedAt': '2026-02-08T07:37:33Z',
#    'content': 'After a sharp sell-off in global enterprise software stocks triggered by fears of AI disruption, markets were reminded how technological shifts can permanently reshape industries, much like the iPhon… [+2633 chars]'},
#   {'source': {'id': 'the-times-of-india', 'name': 'The Times of India'},
#    'author': 'ETMarkets.com',
#    'title': "Gift Nifty falls over 80 pts; here's the trading setup for the day",
#    'description': 'Indian equities surged on Tuesday following a significant trade deal announcement with the US, alleviating tariff concerns. Analysts anticipate continued positive market momentum, driven by recent trade agreements, budget announcements, and the Q3 earnings se…',
#    'url': 'https://economictimes.indiatimes.com/markets/stocks/news/gift-nifty-falls-over-80-pts-heres-the-trading-setup-for-the-day/articleshow/127897479.cms',
#    'urlToImage': 'https://img.etimg.com/thumb/msid-127897493,width-1200,height-630,imgsize-46266,overlay-etmarkets/articleshow.jpg',
#    'publishedAt': '2026-02-04T00:58:43Z',
#    'content': 'Indian Equities witnessed one of the biggest single-day gains on Tuesday after India and US announced a long-awaited trade deal, easing tariff-related concerns that have weighed on Indian markets sin… [+2143 chars]'},
#   {'source': {'id': 'the-times-of-india', 'name': 'The Times of India'},
#    'author': 'Veer Sharma',
#    'title': 'Sensex jumps 600 pts, Nifty at 25,900 tracking global cues and India–US trade optimism',
#    'description': 'Indian stock markets opened with significant gains on Monday. The Sensex and Nifty saw a strong start, rising by 0.7 percent each. Positive news from the India-US trade deal and robust performances in US and Asian markets boosted investor confidence. PSU bank…',
#    'url': 'https://economictimes.indiatimes.com/markets/stocks/news/sensex-jumps-600-pts-nifty-at-25900-tracking-global-cues-and-indiaus-trade-optimism/articleshow/128096117.cms',
#    'urlToImage': 'https://img.etimg.com/thumb/msid-128096080,width-1200,height-630,imgsize-2718446,overlay-etmarkets/articleshow.jpg',
#    'publishedAt': '2026-02-09T03:56:47Z',
#    'content': 'Benchmark indices Sensex and Nifty opened sharply higher on Monday, February 9, rising 0.7% each as positive cues from interim agreement details from the IndiaUS trade deal and a strong finish across… [+3855 chars]'},
#   {'source': {'id': 'the-times-of-india', 'name': 'The Times of India'},
#    'author': 'Veer Sharma',
#    'title': 'Sensex gains 150 pts, Nifty above 25,900 for third straight day; smallcaps outperform',
#    'description': 'Indian stock markets opened on a strong note today. The Sensex and Nifty indices climbed higher, continuing their upward trend for the third day. Small-cap stocks showed impressive gains, outperforming the main indices. This positive momentum signals continue…',
#    'url': 'https://economictimes.indiatimes.com/markets/stocks/news/sensex-gains-150-pts-nifty-above-25900-for-third-straight-day-smallcaps-outperform/articleshow/128140258.cms',
#    'urlToImage': 'https://img.etimg.com/thumb/msid-128140270,width-1200,height-630,imgsize-33426,overlay-etmarkets/articleshow.jpg',
#    'publishedAt': '2026-02-10T04:01:28Z',
#    'content': 'Benchmark indices Sensex and Nifty traded higher on Tuesday, February 10, extending their rally into a third consecutive session. The Nifty Smallcap index continued to outperform the frontline gauges… [+3497 chars]'},
#   {'source': {'id': 'the-times-of-india', 'name': 'The Times of India'},
#    'author': 'ETMarkets.com',
#    'title': 'Sensex, Nifty open little changed ahead of RBI MPC decision; mid, smallcaps slip',
#    'description': "Indian stock markets, Nifty and Sensex, began Friday trading with slight declines. This marks a second consecutive session of losses for the benchmark indices. Investors are adopting a cautious stance. This is due to the upcoming Reserve Bank of India's Monet…",
#    'url': 'https://economictimes.indiatimes.com/markets/stocks/news/sensex-nifty-open-little-changed-ahead-of-rbi-mpc-decision-mid-smallcaps-slip/articleshow/127968078.cms',
#    'urlToImage': 'https://img.etimg.com/thumb/msid-127968216,width-1200,height-630,imgsize-33426,overlay-etmarkets/articleshow.jpg',
#    'publishedAt': '2026-02-06T03:56:14Z',
#    'content': 'Benchmark indices Nifty and Sensex opened lower on Friday, extending losses for a second straight session as investors stayed cautious ahead of the RBIs MPC policy outcome later in the day. Markets l… [+4285 chars]'},
#   {'source': {'id': None, 'name': 'BusinessLine'},
#    'author': 'PTI',
#    'title': 'Inflation data, global trends, Q3 earnings to drive stock market sentiment this week: Analysts',
#    'description': 'This week, key domestic and global events include India’s retail inflation data on February 12 and foreign exchange reserves data on February 13, which will provide insights into price trends and external sector stability',
#    'url': 'https://www.thehindubusinessline.com/markets/inflation-data-global-trends-q3-earnings-to-drive-stock-market-sentiment-this-week-analysts/article70606767.ece',
#    'urlToImage': 'https://bl-i.thgim.com/public/incoming/s42bk0/article70606854.ece/alternates/LANDSCAPE_1200/IMG_Businessman_plan_gra_2_1_PFDTG54D.jpg',
#    'publishedAt': '2026-02-08T07:41:37Z',
#    'content': 'Inflation data, trading activity of foreign investors and global trends would dictate sentiment in the stock market this week, according to analysts.\r\nBesides, geopolitical developments and Q3 earnin… [+2151 chars]'},
#   {'source': {'id': None, 'name': 'BusinessLine'},
#    'author': 'KS Badri Narayanan',
#    'title': 'Markets end firm in roller coaster Budget week; IT stocks lose ₹2.4 lakh crore',
#    'description': 'Markets recover after Budget-day sell-off and IT rout. Sensex, Nifty gain over 1.5% for the week as FPIs turn buyers and Morgan Stanley stays bullish.',
#    'url': 'https://www.thehindubusinessline.com/markets/markets-end-firm-in-roller-coaster-budget-week-it-stocks-lose-24-lakh-crore/article70600585.ece',
#    'urlToImage': 'https://bl-i.thgim.com/public/incoming/g9cgga/article70600928.ece/alternates/LANDSCAPE_1200/Stock%20to%20buy%20today%20i.e.%20individual%20share%20purchasing%20via%20online%202.jpg',
#    'publishedAt': '2026-02-06T14:47:26Z',
#    'content': 'Domestic markets witnessed a rollercoaster ride this week, recovering from a sharp slide on Budget day (on the STT shock) and an AI-induced sell-off in IT stocks. The long-awaited trade deal with the… [+2958 chars]'},
#   {'source': {'id': 'the-times-of-india', 'name': 'The Times of India'},
#    'author': 'Nikhil Agarwal',
#    'title': 'Break below 35,400 on Nifty IT could unleash downside risk for IT stocks: Rupak De',
#    'description': 'Nifty IT remains at a crucial technical level, with a break below 35,400 likely to trigger sharp weakness in the sector, while holding above the level could lead to a meaningful recovery. Meanwhile, FII positioning in index futures has been largely bearish, d…',
#    'url': 'https://economictimes.indiatimes.com/markets/expert-view/break-below-35400-on-nifty-it-could-unleash-downside-risk-for-it-stocks-rupak-de/articleshow/128058509.cms',
#    'urlToImage': 'https://img.etimg.com/thumb/msid-128058520,width-1200,height-630,imgsize-170822,overlay-etmarkets/articleshow.jpg',
#    'publishedAt': '2026-02-08T04:25:09Z',
#    'content': 'If Nifty IT gives a breakdown below 35,400 level, it could potentially create mayhem in the sector, says Rupak De, Senior Technical Analyst at LKP Securities. "On the other hand, if the index sustain… [+4350 chars]'},
#   {'source': {'id': 'the-times-of-india', 'name': 'The Times of India'},
#    'author': 'Shivendra Kumar',
#    'title': 'Societe Generale enters Gokaldas Exports with Rs 41 cr bulk deal as stock rallies 43%',
#    'description': "Gokaldas Exports saw a significant bulk deal as Societe Generale purchased over 5 lakh shares worth Rs 41 crore. The apparel manufacturer's stock has surged 43% in two days, benefiting from a US-India trade deal that slashes tariffs on Indian goods. Despite r…",
#    'url': 'https://economictimes.indiatimes.com/markets/stocks/news/societe-generale-enters-gokaldas-exports-with-rs-41-cr-bulk-deal-as-stock-rallies-43/articleshow/127915065.cms',
#    'urlToImage': 'https://img.etimg.com/thumb/msid-127915055,width-1200,height-630,imgsize-91234,overlay-etmarkets/articleshow.jpg',
#    'publishedAt': '2026-02-04T16:53:14Z',
#    'content': 'Apparel manufacturer Gokaldas Exports witnessed a bulk deal on Wednesday where French multinational bank Societe Generale bought over 5 lakh shares worth Rs 41 crore even as the stock remains in top … [+1822 chars]'},
#   {'source': {'id': 'the-times-of-india', 'name': 'The Times of India'},
#    'author': 'ET Bureau',
#    'title': 'Celebration street! Rupee takes biggest leap in 7 years; stock markets jump 2.5%',
#    'description': "India's rupee and equity markets experienced significant surges following a US-India trade deal that reduced tariffs. The Nifty and Sensex saw substantial intraday gains, while the rupee appreciated, though the central bank intervened to moderate its rise. Th…",
#    'url': 'https://economictimes.indiatimes.com/markets/stocks/news/celebration-street-rupee-takes-biggest-leap-in-7-years-stock-markets-jump-2-5/articleshow/127897539.cms',
#    'urlToImage': 'https://img.etimg.com/thumb/msid-127897540,width-1200,height-630,imgsize-224958,overlay-etmarkets/articleshow.jpg',
#    'publishedAt': '2026-02-04T01:08:16Z',
#    'content': 'The rupee surged the most in seven years and Indias equity gauges logged their largest gains in nine months after Washington agreed, as part of a long-awaited trade deal, to reduce tariffs hurting sh… [+4047 chars]'},
#   {'source': {'id': 'the-times-of-india', 'name': 'The Times of India'},
#    'author': 'Reuters',
#    'title': 'Rupee finds muted relief from weaker dollar; corporate flows dominate',
#    'description': 'The Indian rupee closed \u200da tad weaker on Monday, \u200bunable to benefit from a broadly weaker dollar in \u2060the face of corporate demand for the greenback over a trading session that was also marked by technical glitches.',
#    'url': 'https://economictimes.indiatimes.com/markets/forex/forex-news/rupee-finds-muted-relief-from-weaker-dollar-corporate-flows-dominate/articleshow/128110437.cms',
#    'urlToImage': 'https://img.etimg.com/thumb/msid-128110437,width-1200,height-630,imgsize-84102,overlay-etmarkets/articleshow.jpg',
#    'publishedAt': '2026-02-09T10:45:24Z',
#    'content': 'The Indian rupee closed a tad weaker on Monday, unable to benefit from a broadly weaker dollar in the face of corporate demand for the greenback over a trading session that was also marked by technic… [+1623 chars]'},
#   {'source': {'id': None, 'name': 'Economictimes.com'},
#    'author': 'Economic Times',
#    'title': 'Sensex Today | Nifty 50 | Stock Market Live Updates: Gift Nifty signals negative start; Asian stocks fall',
#    'description': 'Sensex Today | Nifty 50 | Stock Market Live Updates: Indian equities logged one of their sharpest single-day rallies on Tuesday after India and the US unveiled a long-awaited trade agreement, easing tariff worries that have pressured the markets since April 2…',
#    'url': 'https://m.economictimes.com/markets/stocks/live-blog/bse-sensex-today-nifty-50-stock-market-live-updates-gift-nifty-budget-2026-trump-trade-deal-tariff-rate-cut-share-price-04-feb-2026/liveblog/127897795.cms',
#    'urlToImage': 'https://economictimes.indiatimes.com/thumb/msid-127897795,width-1200,height-900,resizemode-4,imglength-11038/markets/stocks/live-blog/bse-sensex-today-nifty-50-stock-market-live-updates-gift-nifty-budget-2026-trump-trade-deal-tariff-rate-cut-share-price-04-feb-2026.jpg',
#    'publishedAt': '2026-02-04T01:51:09Z',
#    'content': 'Sensex Today | Nifty 50 | Stock Market Live Updates: Indian equities logged one of their sharpest single-day rallies on Tuesday after India and the US unveiled a long-awaited trade agreement, easing … [+61 chars]'},
#   {'source': {'id': None, 'name': 'Economictimes.com'},
#    'author': 'Economic Times',
#    'title': 'Sensex Today | Nifty 50 | Stock Market Live Updates: GIFT Nifty signals a gap-up start; Asian shares trade higher',
#    'description': 'Sensex Today | Nifty 50 | Stock Market Live Updates: Indian benchmark indices finished in positive territory, supported by buying in consumer and private banking stocks, even as selling pressure in auto, IT and pharma shares capped gains.',
#    'url': 'https://m.economictimes.com/markets/stocks/live-blog/bse-sensex-today-nifty50-stock-market-live-updates-gift-nifty-sbi-bse-share-price-09-february-2026/liveblog/128092631.cms',
#    'urlToImage': 'https://economictimes.indiatimes.com/thumb/msid-128092631,width-1200,height-900,resizemode-4,imglength-188291/markets/stocks/live-blog/bse-sensex-today-nifty50-stock-market-live-updates-gift-nifty-sbi-bse-share-price-09-february-2026.jpg',
#    'publishedAt': '2026-02-09T01:45:16Z',
#    'content': 'Sensex Today | Nifty 50 | Stock Market Live Updates: Stocks in news: SBI, BSE, Anand Rathi Share, Tata Steel, PFC, Kotak Mahindra Bank\r\nMarkets remained range-bound and closed on a flat note on Frida… [+288 chars]'},
#   {'source': {'id': None, 'name': 'Economictimes.com'},
#    'author': 'Economic Times',
#    'title': 'Sensex Today | Nifty 50 | Stock Market Live Updates: GIFT Nifty signals a positive start; Asian shares trade higher',
#    'description': 'Sensex Today | Nifty 50 | Stock Market Live Updates: Indian benchmark indices extended their winning streak on Monday, marking a second consecutive session of gains, driven by broad-based buying across sectors.',
#    'url': 'https://m.economictimes.com/markets/stocks/live-blog/bse-sensex-today-nifty50-stock-market-live-updates-gift-nifty-titan-bse-share-price-10-february-2026/liveblog/128137147.cms',
#    'urlToImage': 'https://economictimes.indiatimes.com/thumb/msid-128137147,width-1200,height-900,resizemode-4,imglength-188291/markets/stocks/live-blog/bse-sensex-today-nifty50-stock-market-live-updates-gift-nifty-titan-bse-share-price-10-february-2026.jpg',
#    'publishedAt': '2026-02-10T01:51:59Z',
#    'content': 'Sensex Today | Nifty 50 | Stock Market Live Updates: Stocks in news: Titan, BSE, Kotak Mahindra Bank, Marico, Tata Motors PV\r\nIn todays session, shares of Titan, BSE, Kotak Mahindra Bank, Marico and … [+130 chars]'},
#   {'source': {'id': None, 'name': 'BusinessLine'},
#    'author': 'Team BL, KS Badri Narayanan',
#    'title': 'Stock Market Highlights: Sensex settles 208 pts higher at 84,273; Nifty up 67 pts at 25,935',
#    'description': 'Stock Market Today | Stock Market Updates - Find here all the updates related to Sensex, Nifty, BSE, NSE, share prices and Indian stock markets for 10th February 2026.',
#    'url': 'https://www.thehindubusinessline.com/markets/share-market-nifty-sensex-updates-10th-february-2026/article70610658.ece',
#    'urlToImage': 'https://bl-i.thgim.com/public/incoming/5bmz6z/article70610665.ece/alternates/LANDSCAPE_1200/IMG_PO01_Abstract_fin_2_1_95FGSLH8.jpg',
#    'publishedAt': '2026-02-10T11:08:20Z',
#    'content': '<li></li>\r\nFebruary 10, 2026 16:38Stock market live updates today: Trade deal, global cues lift sentiment; Sensex settles 208 points higher at 84,273, Nifty up 67 points at 25,935\r\nEquity benchmark i… [+89876 chars]'},
#   {'source': {'id': 'the-times-of-india', 'name': 'The Times of India'},
#    'author': 'Veer Sharma',
#    'title': 'Market Wrap: Sensex adds 208 points, Nifty extends gain for third session, reclaims 25,900; auto, metal stocks shine',
#    'description': 'Benchmark indices Nifty and Sensex extended their gains for a second straight session on Tuesday, supported by a sharp rally in auto and metal stocks that lifted overall sentiment. Meanwhile, broader markets outperformed, with midcap and smallcap indices risi…',
#    'url': 'https://economictimes.indiatimes.com/markets/stocks/news/market-wrap-sensex-adds-200-points-nifty-extends-gain-for-third-session-reclaims-25900-auto-metal-stocks-shine/articleshow/128153249.cms',
#    'urlToImage': 'https://img.etimg.com/thumb/msid-128153486,width-1200,height-630,imgsize-70488,overlay-etmarkets/articleshow.jpg',
#    'publishedAt': '2026-02-10T10:14:27Z',
#    'content': 'Benchmark indices Nifty and Sensex extended their gains for a second straight session on Tuesday, supported by a sharp rally in auto and metal stocks that lifted overall sentiment. Meanwhile, broader… [+2906 chars]'},
#   {'source': {'id': None, 'name': 'BusinessLine'},
#    'author': 'Team BL, KS Badri Narayanan',
#    'title': 'Q3 Results Today Live: Bharti Airtel, LIC, Hero MotoCorp, Tata Motors PV, IOC, Kaynes Tech, Mazagon, Hitachi Energy, Godrej Properties, PhysicsWallah, Page Ind, Max Healthcare to announce Q3 results, Trent, Bajaj Finserv, Apollo Tyres, Emami shares in focus',
#    'description': 'Q3 Results Today, 05th Feb 2026 Live Updates: Find all the latest Q3 results 2026 updates of Bharti Airtel, Life Insurance Corporation of India, Indian Oil Corporation, Tata Motors Passenger Vehicles, Power Finance Corporation, Hero MotoCorp, Max Healthcare I…',
#    'url': 'https://www.thehindubusinessline.com/markets/stock-markets/q3-results-today-live-updates-bharti-airtel-lic-hero-motocorp-kaynes-hitachi-godrej-properties-max-healthcare-ioc-tata-motors-pv-physicswallah-trent-bajaj-finserv-results-05-feb-2026/article70594308.ece',
#    'urlToImage': 'https://bl-i.thgim.com/public/incoming/zf4ff0/article70594294.ece/alternates/LANDSCAPE_1200/BL13_Think_accounting.jpg',
#    'publishedAt': '2026-02-05T04:00:53Z',
#    'content': '<li></li>\r\nFebruary 5, 2026 09:38JSW Cement Q3 results live:\r\nJSW Cement Ltd. | CMP Rs. 116 | M Cap Rs. 15815 Cr | 52 W H/L 162/107\r\n(Nirmal Bang Retail Research)\r\nResult is above expectations\r\nReven… [+5800 chars]'},
#   {'source': {'id': None, 'name': 'Business Standard'},
#    'author': 'Deepak Korgaonkar',
#    'title': "Nifty PSU Bank index rallies nearly 4%, hits new high; what's driving PSBs?",
#    'description': 'In the past one month, the Nifty PSU Bank index has outperformed the market by surging 7 per cent, as against 0.5 per cent gain in the Nifty 50.',
#    'url': 'https://www.business-standard.com/markets/news/nifty-psu-bank-index-rallies-nearly-4-hits-new-high-what-s-driving-psbs-126020900232_1.html',
#    'urlToImage': 'https://bsmedia.business-standard.com/_media/bs/img/article/2024-10/11/thumb/fitandfill/1200X630/1728667380-7191.jpg',
#    'publishedAt': '2026-02-09T04:55:05Z',
#    'content': 'In the past one month, the Nifty PSU Bank index has outperformed the market by surging 7 per cent, as against 0.5 per cent gain in the Nifty 50.\r\nIllustration: Binay Sinha\r\nDeepak KorgaonkarMumbai\r\nN… [+5467 chars]'},
#   {'source': {'id': 'the-times-of-india', 'name': 'The Times of India'},
#    'author': 'Shivendra Kumar',
#    'title': 'Ahead of Market: 10 things that will decide stock market action on Tuesday',
#    'description': 'Indian markets extended gains as Nifty and Sensex rose for a second session, led by financials, auto and consumer stocks. Nifty crossed 25,800, reclaimed key averages and signalled bullish momentum, with analysts eyeing 26,000–26,200 while support holds near …',
#    'url': 'https://economictimes.indiatimes.com/markets/stocks/news/ahead-of-market-10-things-that-will-decide-stock-market-action-on-tuesday/articleshow/128121708.cms',
#    'urlToImage': 'https://img.etimg.com/thumb/msid-128121723,width-1200,height-630,imgsize-105340,overlay-etmarkets/articleshow.jpg',
#    'publishedAt': '2026-02-09T16:04:48Z',
#    'content': 'Indian benchmark indices closed higher on Monday for the second session in a row, supported by broad-based buying across sectors, with financials, auto and consumer stocks leading the gains. The Nift… [+5417 chars]'},
#   {'source': {'id': None, 'name': 'Business Standard'},
#    'author': 'Capital Market',
#    'title': 'Nifty trades above 25,800 level; PSU Bank shares rally',
#    'description': 'PSU Bank shares jumped after declining in the past trading session.',
#    'url': 'https://www.business-standard.com/markets/capital-market-news/nifty-trades-above-25-800-level-psu-bank-shares-rally-126020900788_1.html',
#    'urlToImage': 'https://www.business-standard.com/assets/web-assets/images/Business_Standard_1_685x385.jpg',
#    'publishedAt': '2026-02-09T10:30:19Z',
#    'content': 'The domestic equity benchmarks traded with moderate gains in the morning trade as investors sentiment remained optimistic following the recently signed India- US trade deal agreement. market particip… [+1913 chars]'},
#   {'source': {'id': 'the-times-of-india', 'name': 'The Times of India'},
#    'author': 'Veer Sharma',
#    'title': 'Sensex falls over 200 pts, Nifty below 25,700; mid, smallcaps slip up to 1%',
#    'description': 'Benchmark indices Nifty and Sensex opened lower on Thursday, ending a three-day rally as investors booked profits at higher levels. Metal and pharma stocks were the biggest decliners, with the broader market also experiencing a downturn. The BSE Sensex droppe…',
#    'url': 'https://economictimes.indiatimes.com/markets/stocks/news/sensex-falls-over-200-pts-nifty-below-25700-mid-smallcaps-slip-up-to-1/articleshow/127923276.cms',
#    'urlToImage': 'https://img.etimg.com/thumb/msid-127923279,width-1200,height-630,imgsize-24880,overlay-etmarkets/articleshow.jpg',
#    'publishedAt': '2026-02-05T04:06:06Z',
#    'content': 'Benchmark indices Nifty and Sensex traded lower on Thursday, snapping a three-day rally as investors booked profit at elevated levels. Metal and pharma stocks were the worst performers, sliding 2% an… [+3767 chars]'},
#   {'source': {'id': None, 'name': 'Ndtvprofit.com'},
#    'author': 'NDTV Profit News',
#    'title': 'Hindustan Copper Q3 Results: Date, Dividend News, Share Price History',
#    'description': 'Shares of Hindustan Copper have fallen 9.94% in the past five trading sessions on the NSE.',
#    'url': 'https://www.ndtvprofit.com/markets/hindustan-copper-q3-results-date-dividend-news-share-price-history-and-more-10936100',
#    'urlToImage': 'https://c.ndtvimg.com/2026-02/uvrq7ha4_hindustan-copper_625x300_04_February_26.jpg?im=FeatureCrop,algorithm=dnn,width=1080,height=607',
#    'publishedAt': '2026-02-04T03:55:43Z',
#    'content': "Hindustan Copper Ltd. will announce results for the third quarter of FY26 this week. It is a Schedule A' Mini-Ratna, Category-I Central Public Sector Enterprise (CPSE) under the Ministry of Mines. In… [+2455 chars]"},
#   {'source': {'id': 'the-times-of-india', 'name': 'The Times of India'},
#    'author': 'ETMarkets.com',
#    'title': "Gift Nifty falls over 100 pts; here's trading setup for the day",
#    'description': 'Indian stock markets moved sideways on Thursday. Investors adopted a cautious stance, awaiting new domestic cues. The Nifty index remained within a narrow band, struggling to break out. Analysts anticipate continued range-bound trading for the index. Select i…',
#    'url': 'https://economictimes.indiatimes.com/markets/stocks/news/gift-nifty-falls-over-100-pts-heres-trading-setup-for-the-day/articleshow/127962843.cms',
#    'urlToImage': 'https://img.etimg.com/thumb/msid-127963135,width-1200,height-630,imgsize-46266,overlay-etmarkets/articleshow.jpg',
#    'publishedAt': '2026-02-06T01:08:34Z',
#    'content': 'Indian equity markets traded in a tight range on Thursday, signalling a wait-and-watch phase as investors remained cautious in the absence of fresh domestic triggers. Analysts say Nifty remained lock… [+1813 chars]'},
#   {'source': {'id': 'the-times-of-india', 'name': 'The Times of India'},
#    'author': 'Shivendra Kumar',
#    'title': 'Ahead of Market: 10 things that will decide stock market action on Friday',
#    'description': 'Indian equities ended lower as Nifty and Sensex snapped gains amid broad selling led by financials, autos and IT. Analysts see consolidation, with key supports intact, resistance capping rebounds, and stock-specific opportunities until RBI policy cues emerge …',
#    'url': 'https://economictimes.indiatimes.com/markets/stocks/news/ahead-of-market-10-things-that-will-decide-stock-market-action-on-friday/articleshow/127944298.cms',
#    'urlToImage': 'https://img.etimg.com/thumb/msid-127944403,width-1200,height-630,imgsize-105340,overlay-etmarkets/articleshow.jpg',
#    'publishedAt': '2026-02-05T16:07:47Z',
#    'content': 'Indian benchmark indices snapped their two-day winning streak on Thursday, ending lower amid broad-based selling pressure. Financials, auto and IT stocks led the declines. The Nifty closed at 25,642.… [+4870 chars]'},
#   {'source': {'id': 'the-times-of-india', 'name': 'The Times of India'},
#    'author': 'ETMarkets.com',
#    'title': "Gift Nifty signals positive start; here's trading setup for the day",
#    'description': "Indian equities consolidated on Wednesday after a recent rally, with investors awaiting clarity on the India-US trade deal and the RBI's interest rate decision. Markets are expected to remain firm with a positive bias, driven by trade deals, budget announceme…",
#    'url': 'https://economictimes.indiatimes.com/markets/stocks/news/gift-nifty-signals-positive-start-heres-trading-setup-for-the-day/articleshow/127921380.cms',
#    'urlToImage': 'https://img.etimg.com/thumb/msid-127921400,width-1200,height-630,imgsize-1064824,overlay-etmarkets/articleshow.jpg',
#    'publishedAt': '2026-02-05T01:02:02Z',
#    'content': "Indian equities consolidated on Wednesday, a day after its rally on the back of the India-US trade deal, as investors await further clarity on the agreement and look forward to RBI's interest rate de… [+2311 chars]"},
#   {'source': {'id': 'the-times-of-india', 'name': 'The Times of India'},
#    'author': 'Veer Sharma',
#    'title': 'Desi boys beat FIIs as DII holding in Nifty50 touches all-time high of 24.8%',
#    'description': 'Domestic institutional investors have emerged as the dominant force in the Nifty50, with holdings rising to 24.8% as of December 2025. FIIs reduced exposure amid Rs 1.6 lakh crore sales, while promoter stakes fell to a record low. DIIs gained across sectors a…',
#    'url': 'https://economictimes.indiatimes.com/markets/stocks/news/desi-boys-beat-fiis-as-dii-holding-in-nifty50-touches-all-time-high-of-24-8/articleshow/128105756.cms',
#    'urlToImage': 'https://img.etimg.com/thumb/msid-128105741,width-1200,height-630,imgsize-30852,overlay-etmarkets/articleshow.jpg',
#    'publishedAt': '2026-02-09T08:35:40Z',
#    'content': 'Domestic institutional investors are increasingly calling the shots in Indias benchmark index, with their stake in the Nifty-50 climbing to a record 24.8% as of December 2025, a historic shift that s… [+3090 chars]'},
#   {'source': {'id': 'the-times-of-india', 'name': 'The Times of India'},
#    'author': 'ETMarkets.com',
#    'title': 'Sensex falls over 450 pts, Nifty below 25,700 global tech sell-off spills into D-Street',
#    'description': 'Indian equity benchmarks Nifty and Sensex opened lower on Wednesday, dragged down by a significant sell-off in IT stocks following a major tech rout in the US. Investors also booked profits after a strong rally, while escalating geopolitical tensions added to…',
#    'url': 'https://economictimes.indiatimes.com/markets/stocks/news/sensex-falls-over-450-pts-nifty-below-25700-global-tech-sell-off-spills-into-d-street/articleshow/127899311.cms',
#    'urlToImage': 'https://img.etimg.com/thumb/msid-127899304,width-1200,height-630,imgsize-83354,overlay-etmarkets/articleshow.jpg',
#    'publishedAt': '2026-02-04T03:59:27Z',
#    'content': 'Benchmark indices Nifty and Sensex opened lower on Wednesday as a sharp sell-off in IT stocks weighed on sentiment, with the sectoral index sliding nearly 6% after a major tech rout in the US. Invest… [+4406 chars]'},
#   {'source': {'id': None, 'name': 'Business Standard'},
#    'author': 'Ananya Chaudhuri',
#    'title': 'Hindustan Zinc, JNCASR develop zinc-ion battery prototype; stock rises 3%',
#    'description': 'Shares of Hindustan Zinc rose on Monday as the company developed, in collaboration with the JNCACR, stable and reliable zinc-ion battery pouch cell prototypes for large-scale renewable energy storage',
#    'url': 'https://www.business-standard.com/markets/news/hindustan-zinc-jncasr-develop-zinc-ion-battery-prototype-stock-rises-3-126020900411_1.html',
#    'urlToImage': 'https://bsmedia.business-standard.com/_media/bs/img/article/2023-03/21/thumb/fitandfill/1200X630/1679402544-2913.jpg',
#    'publishedAt': '2026-02-09T07:35:41Z',
#    'content': 'Shares of Hindustan Zinc rose on Monday as the company developed, in collaboration with the JNCACR, stable and reliable zinc-ion battery pouch cell prototypes for large-scale renewable energy storage… [+3699 chars]'},
#   {'source': {'id': None, 'name': 'Business Standard'},
#    'author': 'Capital Market',
#    'title': 'Indices trade firm in early trade; breadth strong',
#    'description': 'Barring FMCG index the lone laggard, all the sectoral indices on the NSE were traded in green.',
#    'url': 'https://www.business-standard.com/markets/capital-market-news/indices-trade-firm-in-early-trade-breadth-strong-126020900193_1.html',
#    'urlToImage': 'https://www.business-standard.com/assets/web-assets/images/Business_Standard_1_685x385.jpg',
#    'publishedAt': '2026-02-09T04:21:40Z',
#    'content': 'The key equity indices traded with modest gains in early trade as investors sentiment remained optimistic following the recently signed India- US trade deal agreement and positive global cues. Invest… [+4147 chars]'},
#   {'source': {'id': 'the-times-of-india', 'name': 'The Times of India'},
#    'author': 'Pranav Mukul',
#    'title': 'Mutual funds adopt India Inc’s next gen companies with open arms',
#    'description': 'These institutions accumulated significant stakes in consumer internet firms Eternal, Swiggy, Nykaa and PB Fintech this past year, despite mixed share performance. They also bought into companies such as Lenskart, Groww, Meesho and PhysicsWallah that entered …',
#    'url': 'https://economictimes.indiatimes.com/tech/startups/mutual-funds-adopt-india-incs-next-gen-companies-with-open-arms/articleshow/128126202.cms',
#    'urlToImage': 'https://img.etimg.com/thumb/width-1200,height-900,imgsize-349886,resizemode-75,msid-128126202/tech/startups/mutual-funds-adopt-india-incs-next-gen-companies-with-open-arms.jpg',
#    'publishedAt': '2026-02-10T00:30:00Z',
#    'content': 'Domestic mutual funds held shares worth Rs 1.77 lakh crore in about two dozen new-age companies at the end of 2025, nearly double compared with Rs 95,000 crore a year earlier, according to shareholdi… [+4295 chars]'},
#   {'source': {'id': 'the-times-of-india', 'name': 'The Times of India'},
#    'author': 'Pranav Mukul',
#    'title': 'Domestic MFs double their holdings in new-age startups over a year',
#    'description': 'These institutions accumulated significant stakes in consumer internet firms Eternal, Swiggy, Nykaa and PB Fintech this past year, despite mixed share performance. They also bought into companies such as Lenskart, Groww, Meesho and PhysicsWallah that entered …',
#    'url': 'https://economictimes.indiatimes.com/tech/startups/domestic-mfs-double-their-holdings-in-new-age-startups-over-a-year/articleshow/128126202.cms',
#    'urlToImage': 'https://img.etimg.com/thumb/width-1200,height-900,imgsize-134172,resizemode-75,msid-128126202/tech/startups/domestic-mfs-double-their-holdings-in-new-age-startups-over-a-year.jpg',
#    'publishedAt': '2026-02-10T00:30:00Z',
#    'content': 'Domestic mutual funds held shares worth Rs 1.77 lakh crore in about two dozen new-age companies at the end of 2025, nearly double compared with Rs 95,000 crore a year earlier, according to shareholdi… [+4295 chars]'},
#   {'source': {'id': None, 'name': 'CNBC'},
#    'author': 'Yeo Boon Ping',
#    'title': 'CNBC Daily Open: Alphabet could more than double its capex in 2026, unsettling investors',
#    'description': 'Alphabet expects capital expenditure for 2026 to come in between $175 billion and $185 billion — at the higher end, capex will more than double from last year.',
#    'url': 'https://www.cnbc.com/2026/02/05/cnbc-daily-open-alphabet-could-more-than-double-its-capex-in-2026-unsettling-investors.html',
#    'urlToImage': 'https://image.cnbcfm.com/api/v1/image/108261645-1770242575711-gettyimages-2259951688-_73a9042_xrkcxizk.jpeg?v=1770242732&w=1920&h=1080',
#    'publishedAt': '2026-02-05T07:30:01Z',
#    'content': "Alphabet's fourth-quarter earnings and revenue beat Wall Street expectations. Its cloud unit dazzled, notching a nearly 48% increase in revenue from a year earlier. \r\nThe tech giant expects capital e… [+3731 chars]"},
#   {'source': {'id': None, 'name': 'BusinessLine'},
#    'author': 'Team BL, KS Badri Narayanan',
#    'title': 'Q3 Results Today Highlights: LIC, Indian Oil, Godrej Properties, Suzlon, JSW Cement post gains; Tata Motors, Bharti Airtel, Hexaware, Jaiprakash Power slide',
#    'description': 'Q3 Results Today, 05th Feb 2026 Highlights: Find all the latest Q3 results 2026 updates of Bharti Airtel, Life Insurance Corporation of India, Indian Oil Corporation, Tata Motors Passenger Vehicles, Power Finance Corporation, Hero MotoCorp, Max Healthcare Ins…',
#    'url': 'https://www.thehindubusinessline.com/markets/stock-markets/q3-results-today-highlights-bharti-airtel-lic-hero-motocorp-kaynes-hitachi-godrej-properties-max-healthcare-ioc-tata-motors-pv-physicswallah-trent-bajaj-finserv-results-05-feb-2026/article70594308.ece',
#    'urlToImage': 'https://bl-i.thgim.com/public/incoming/zf4ff0/article70594294.ece/alternates/LANDSCAPE_1200/BL13_Think_accounting.jpg',
#    'publishedAt': '2026-02-05T14:56:47Z',
#    'content': '<li></li>\r\nFebruary 5, 2026 20:22Berger Paints Q3 results live: Net profit slips 8.3% to Rs 271.35 cr\r\nBerger Paints India on Thursday reported a decline of 8.3 per cent in its consolidated net profi… [+26672 chars]'},
#   {'source': {'id': 'the-times-of-india', 'name': 'The Times of India'},
#    'author': 'Akash Podishetti',
#    'title': 'Reeling in bear market, should investors buy smallcap stocks after India-US trade deal?',
#    'description': "India's smallcap stocks, after a sharp correction, are seeing a potential turning point following the India-US trade deal. While export-oriented companies may benefit from reduced tariffs, analysts advise a selective, bottom-up approach, focusing on fundament…",
#    'url': 'https://economictimes.indiatimes.com/markets/stocks/news/reeling-in-bear-market-should-investors-buy-smallcap-stocks-after-india-us-trade-deal/articleshow/127899650.cms',
#    'urlToImage': 'https://img.etimg.com/thumb/msid-127899666,width-1200,height-630,imgsize-16064,overlay-etmarkets/articleshow.jpg',
#    'publishedAt': '2026-02-04T04:23:10Z',
#    'content': "After two years of exceptional gains, India's smallcap stocks have gone through a sharp and painful correction. The question now facing investors is whether the recent India-US trade deal marks a tur… [+6077 chars]"},
#   {'source': {'id': None, 'name': 'Ndtvprofit.com'},
#    'author': 'NDTV Profit Research',
#    'title': 'All You Need To Know Going Into Trade On Wednesday',
#    'description': 'Stocks in news, earnings post market hours, bulk and block deals, F&amp;O cues and much more!',
#    'url': 'https://www.ndtvprofit.com/markets/stock-market-today-all-you-need-to-know-going-into-trade-on-feb-4-10941062',
#    'urlToImage': 'https://c.ndtvimg.com/2026-02/mrrl8q28_trade-setup_625x300_02_February_26.jpg?im=FeatureCrop,algorithm=dnn,width=1080,height=607',
#    'publishedAt': '2026-02-04T00:30:01Z',
#    'content': 'Good Morning!\r\nThe GIFT Nifty is trading with losses of around 0.3%\xa0at 25,779, indicating a negative open for the benchmark index. US and European index futures, meanwhile, are trading marginally low… [+19325 chars]'},
#   {'source': {'id': None, 'name': 'BusinessLine'},
#    'author': 'Anupama Ghosh',
#    'title': 'India-US trade deal sets stage for sustained FPI inflows as foreign investors return with $897 million',
#    'description': 'The India-US trade deal boosts foreign portfolio investments in India, with $897 million inflows signaling renewed investor confidence.',
#    'url': 'https://www.thehindubusinessline.com/markets/stock-markets/india-us-trade-deal-sets-stage-for-sustained-fpi-inflows-as-foreign-investors-return-with-897-million/article70606895.ece',
#    'urlToImage': 'https://bl-i.thgim.com/public/incoming/k87eeo/article70606961.ece/alternates/LANDSCAPE_1200/BL10_Think_India_US_partnership_2.jpg',
#    'publishedAt': '2026-02-08T08:34:08Z',
#    'content': 'The India-US trade deal is expected to trigger sustained foreign portfolio inflows into Indian markets as overseas investors regain confidence in the countrys growth trajectory, with the week ending … [+5214 chars]'},
#   {'source': {'id': None, 'name': 'Protothema.gr'},
#    'author': 'Newsroom',
#    'title': 'The “poison” poll for Karystianou and Tsipras, Thymios at M.M., Frangou in Argentina, and the Romanian billionaires at Praktiker',
#    'description': 'Greek Shipowners Behind the Scenes of Global Energy & the “Hellenic Ammunition”\nThe post The “poison” poll for Karystianou and Tsipras, Thymios at M.M., Frangou in Argentina, and the Romanian billionaires at Praktiker appeared first on ProtoThema English.',
#    'url': 'https://en.protothema.gr/2026/02/04/the-poison-poll-for-karystianou-and-tsipras-thymios-at-m-m-frangou-in-argentina-and-the-romanian-billionaires-at-praktiker/',
#    'urlToImage': 'https://en.protothema.gr/wp-content/uploads/2024/06/ProtothemaEn.png',
#    'publishedAt': '2026-02-04T10:43:06Z',
#    'content': 'Hello, sometimes the information I have is not completely freshwhat we call fish of the daybut I think it is always reliable. So Im passing on to you a poll that was obviously not published, because … [+24811 chars]'}]}
